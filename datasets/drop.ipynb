# %%
import numpy as np
import pandas as pd

# %%
db_table = pd.read_csv('Appendix-D-to-Advisory-Group-Memo-38-Statistics-on-District-Adult-Criminal-Charges-and-Convictions.xlsx - 2019 (95% Quant).csv', encoding='utf-8')

# %%
db_table.head()
# Out:
#   Micro Citation                                Micro Citation Name  \
# 0    22DC210%1-Y      Abuse of a Vulnerable Adult or Elderly Person
# 1      22DC210%3                Accessory to a Crime After the Fact
# 2     22DC20%0%1                                 Aggravated Assault
# 3     22DC30%0%8  Aggravated Assault (Causes Serious Bodily Injury)
# 4    22DC80%1(a)                    Aggravated Assault (Grave Risk)
#
#   Macro Citation              Macro Citation Name Social Harm  \
# 0      22DC210%1              First Degree Murder      PERSON
# 1      22DC210%3             Second Degree Murder      PERSON
# 2     22DC20%0%1                       Kidnapping      PERSON
# 3     22DC30%0%8  First Degree Child Sexual Abuse      PERSON
# 4       22DC80%1                         Burglary    PROPERTY
#
#   # Charges (Grand Total) % All Charges (For Any Offense)  \
# 0                      34                           0%.2%
# 1                      36                           0%.2%
# ...

# %%
db_table.shape
# Out:
# (159, 167)

# %%
db_table2=db_table.replace('%','',regex = True)

# %%
db_table2.to_csv("2019 (95% Quant).csv",index=False)

# %%
# Out:
#          Micro Citation                                Micro Citation Name  \
# 0            05DC117.05      Abuse of a Vulnerable Adult or Elderly Person
# 1        07DC2502.01(a)                Accessory to a Crime After the Fact
# 2        07DC2506.01(a)                                 Aggravated Assault
# 3        07DC2506.01(b)  Aggravated Assault (Causes Serious Bodily Injury)
# 4               08DC902                    Aggravated Assault (Grave Risk)
# ..                  ...                                                ...
# 170  50DC2201.05b(b)(2)         Voyeurism (Distributing and Disseminating)
# 171  50DC2201.05c(a)(1)                  Voyeurism (Image of Private Area)
# 172  50DC2201.05c(a)(2)                              Voyeurism (Recording)
# 173         50DC2203.01          Wearing Hood or Mask With Unlawful Intent
# 174       50DC2203.01-X                             Work Release Violation
#
# ...

# %%
for i in range(159):
    for j in range(167):
        db_table.iloc[i][j].replace('%','')

db_table
# Out:
#            Micro Citation                                Micro Citation Name  \
# 0      48DC90%4.0%1(d)(1)      Abuse of a Vulnerable Adult or Elderly Person
# 1    48DC90%4.0%1(a)(1)-Y  Abuse of a Vulnerable Adult or Elderly Person ...
# 2          23DC1327(a)(2)                Accessory to a Crime After the Fact
# 3          22DC40%4(a)(1)          Accessory to a Crime After the Fact (ADW)
# 4             22DC3212(b)                                 Aggravated Assault
# ..                    ...                                                ...
# 154              22DC3242  Unlawful Possession of a Firearm (Prior Convic...
# 155             22DC240%3                  Unlawful Possession of Ammunition
# 156   0%7DC250%2.0%1(a)-X              Violation of Protection Order (Civil)
# 157              22DC3231                              Voyeurism (Recording)
# 158      50%DC2421.0%4(d)  Work Release Violation (Failure to Return to C...
#
# ...

# %%
i = 0
j = 0
db_table.iloc[i][j].replace('%','')
# Out:
# '48DC904.01(d)(1)'
